# %% [markdown]
# ## City of LA vax data to Socrata

# %%
"""
# !pip install google-cloud-bigquery 
# !pip install sqlalchemy<1.4.0  
# !pip install ibis>=1.4.0, ibis-framework>=1.4.0, ibis-framework[bigquery], ibis-bigquery>=0.1.1
# !pip install gcsfs


#select * from ita-electedoffice-vaccines.electedoffice_vaccines_dashboard.la_city_vaccines  limit 100
"""

# %%
import gcsfs
import os
import pandas as pd


CREDENTIAL = "../gcp-credential.json"
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = f'{CREDENTIAL}'

gs = gcsfs.GCSFileSystem(project="ita-datalakepoc")

BUCKET_NAME = "electedoffice_vaccines_dashboard"

# %%
df = pd.read_csv(f"gcs://{BUCKET_NAME}/data/la_city_vaccines.csv", 
                 dtype={"patient_zipcode": "str"})  
df.head()
# Out:
#       site_type agegroup   race_ethnicity patient_race  \
# 0     City Site    30-49            Asian        Asian
# 1     City Site    30-49            White        White
# 2   Mobile Site    50-64  Hispanic_Latino        Other
# 3  Private Site    30-49            White        White
# 4     City Site    30-49            Asian        Asian
#
#         patient_ethnicity patient_gender  \
# 0  Not of Hispanic Origin           Male
# 1  Not of Hispanic Origin           Male
# 2         Hispanic Origin         Female
# 3  Not of Hispanic Origin           Male
# 4  Not of Hispanic Origin           Male
#
#                                    vaccine_site_name appointment_booked_time  \
# 0  University of Southern California (USC) - Mode...     2021-04-22 16:00:00
# 1  University of Southern California (USC) - Pfiz...     2021-04-22 23:00:00
# 2            Green Meadows - Pfizer (Age 12+) - LAFD     2021-03-16 09:00:00
# 3  Los Angeles World Airport (LAWA) - Pfizer - LA...     2021-03-29 10:00:00
# 4  Dodger Stadium (Academy Rd) - Moderna (Age 18+...     2021-04-09 18:00:00
#
#   appointment_date appt_status patient_zipcode  patient_age  vaccine_id  \
# 0       2021-04-22  Discharged           91206         45.0     2608786
# 1       2021-04-22  Discharged           90049         44.0     2348374
# 2       2021-03-16  Discharged             NaN         55.0     1953612
# 3       2021-03-29  Discharged           90045         33.0     1924889
# 4       2021-04-09    Upcoming           92833         45.0     2102223
#
#    shot_number    brand       main_site    peh    apptdate
# 0  Second Shot  Moderna             USC  False  2021-05-11
# 1  Second Shot   Pfizer             USC  False  2021-04-23
# 2  Second Shot   Pfizer   Green Meadows    NaN  2021-03-30
# 3  Second Shot   Pfizer            LAWA  False  2021-03-29
# 4  Second Shot      NaN  Dodger Stadium  False  1972-07-03

# %%
check_dates = df[["appointment_date", "apptdate"]]
print("appointment_date <= apptdate -- CORRECT")
print(len(check_dates[check_dates.appointment_date <= check_dates.apptdate]))
print("appointment_date > apptdate -- INCORRECT")
print(len(check_dates[check_dates.appointment_date > check_dates.apptdate]))
# Out:
# appointment_date <= apptdate -- CORRECT
# 1323884
# appointment_date > apptdate -- INCORRECT
# 283997

# %%
check_dates[check_dates.appointment_date > check_dates.apptdate].apptdate.value_counts()
# Out:
# 1972-07-03    254608
# 2021-01-09      4241
# 2021-01-08      3984
# 2021-01-07      3587
# 2021-01-06      1994
#                ...
# 2021-05-17         1
# 2021-06-12         1
# 2021-05-20         1
# 2021-07-16         1
# 2021-06-19         1
# Name: apptdate, Length: 128, dtype: int64

# %%
group_cols = [
    "appointment_date",
    "site_type", "agegroup", "race_ethnicity", 
    "patient_race", "patient_ethnicity", "patient_gender", 
    "vaccine_site_name", "shot_number", "brand", "appt_status",
]

df2 = (df.groupby(group_cols)
       .agg({"vaccine_id": "count"})
       .reset_index()
       .rename(columns = {
           "appointment_date": "date",
           "vaccine_id": "num_vaccines"})
      )


df2.head()
# Out:
#   appointment_date  site_type agegroup   race_ethnicity patient_race  \
# 0       2021-01-10  City Site    18-29            Asian        Asian
# 1       2021-01-10  City Site    18-29            Asian        Asian
# 2       2021-01-10  City Site    18-29            Asian        Asian
# 3       2021-01-10  City Site    18-29            Black        Black
# 4       2021-01-10  City Site    18-29  Hispanic_Latino        Other
#
#         patient_ethnicity patient_gender  \
# 0  Not of Hispanic Origin         Female
# 1  Not of Hispanic Origin           Male
# 2  Not of Hispanic Origin           Male
# 3  Not of Hispanic Origin         Female
# 4         Hispanic Origin         Female
#
#                          vaccine_site_name shot_number    brand appt_status  \
# 0  Lincoln Park - Moderna (Age 18+) - LAFD  First Shot  Moderna  Discharged
# 1  Lincoln Park - Moderna (Age 18+) - LAFD  First Shot  Moderna  Discharged
# 2  Lincoln Park - Moderna (Age 18+) - LAFD  First Shot  Moderna  Monitoring
# 3  Lincoln Park - Moderna (Age 18+) - LAFD  First Shot  Moderna  Discharged
# 4  Lincoln Park - Moderna (Age 18+) - LAFD  First Shot  Moderna  Discharged
#
#    num_vaccines
# 0            11
# 1             5
# 2             1
# 3             2
# 4             5

# %%
df2.to_csv("la-city-vaccines.csv", index=False)

# %%
os.remove("la-city-vaccines.csv")
